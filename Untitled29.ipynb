# %% [markdown]
# <a href="https://colab.research.google.com/github/sandihermawan505/Handphone/blob/master/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade tensorflow
# !pip install emoji
# !pip install fasttext
# !pip install re
# !pip install sastrawi
# Out:
# Requirement already up-to-date: tensorflow in /usr/local/lib/python3.6/dist-packages (2.4.0)
# ...
# ERROR: Could not find a version that satisfies the requirement re (from versions: none)
# ERROR: No matching distribution found for re
# ...

# %%
import numpy as np 
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow_hub as hub
import emoji
import os
import time
import sys
import fasttext
import re
import nltk 
nltk.download('punkt')
from nltk.corpus import stopwords
import tensorflow as tf
tf.keras.backend.clear_session()

import itertools
import collections
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
#load data 
for dirname, _, filenames in os.walk('/content/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /content/input/data_cleaned_j.txt
# /content/input/data_ready.csv
# /content/input/data_cleaned.txt
# /content/input/dataset_tweet_sentimen_tayangan_tv.csv

# %%
tf.__version__
# Out:
# '2.4.0'

# %%
# data = pd.read_csv("/content/input/dataset_tweet_sentimen_tayangan_tv.csv")
# data_df = data.loc[:,['Text Tweet','Sentiment']]
# data_df.tail()

# %%
data = pd.read_csv("/content/input/data_ready.csv", delimiter = ";")
data_df = data.loc[:,['Text Tweet','Sentiment']]
data_df.tail()
# Out:
#                                              Text Tweet Sentiment
# 2035  b'Yang besok pada mau demo otaknya pada dimana...  negative
# 2036  b'YANG DEMO HABIB ANGAKATAN BERAPA NIH #sayabe...  negative
# 2037  b'Yang muslim sedang bingung tentang kemuslima...  negative
# 2038                            b'Yg bikin MASALAH &amp  negative
# 2039  b'Zona Merah Covid-19 Jabar Bertambah, Ridwan ...  negative

# %%
train = data_df
train.tail()
# Out:
#                                              Text Tweet Sentiment
# 2035  b'Yang besok pada mau demo otaknya pada dimana...  negative
# 2036  b'YANG DEMO HABIB ANGAKATAN BERAPA NIH #sayabe...  negative
# 2037  b'Yang muslim sedang bingung tentang kemuslima...  negative
# 2038                            b'Yg bikin MASALAH &amp  negative
# 2039  b'Zona Merah Covid-19 Jabar Bertambah, Ridwan ...  negative

# %%
# test = data_df[2000:]
# test.head()

# %%
# check class distribution in train dataset
from scipy import stats
data_df.groupby(['Sentiment']).size()
# Out:
# Sentiment
# negative    1063
# positive     973
# dtype: int64

# %%
colors = list('rgb') #rgbkm
count_classes = pd.value_counts(train['Sentiment'], sort = True)
count_classes.plot(kind = 'bar', rot=0, color=colors, figsize=(6,4))
plt.title("Class Distribution")
plt.xlabel("class")
plt.ylabel("Count");

# %%
train.head()
train['Text Tweet'].head()
# Out:
# 0    b'"(Pemeriksaan ahli pidana) untuk memastikan ...
# 1    b'"... jadi lewat statement ini saja bahwa hid...
# 2    b'"... Menurut saya, semua kekisruhan yang ber...
# 3    b'"... nanti saya yang akan menjadi penerima p...
# 4    b"@jr_kw19 @PartBurungGalak Warga Muslim.Yang ...
# Name: Text Tweet, dtype: object

# %%
#import contractions list and remove it in the next step
# A list of contractions from http://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python
contractions = { 
"spt" : "seperti",
"ketum" : "ketua umum",
"menristek" : "kementerian riset dan teknologi",
"loew" : "anda",
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he's": "he is",
"how'd": "how did",
"how'll": "how will",
"how's": "how is",
"i'd": "i would",
"i'll": "i will",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'll": "it will",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"must've": "must have",
"mustn't": "must not",
"needn't": "need not",
"oughtn't": "ought not",
"shan't": "shall not",
"sha'n't": "shall not",
"she'd": "she would",
"she'll": "she will",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"that'd": "that would",
"that's": "that is",
"there'd": "there had",
"there's": "there is",
"they'd": "they would",
"they'll": "they will",
"they're": "they are",
"they've": "they have",
"wasn't": "was not",
"we'd": "we would",
"we'll": "we will",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"where'd": "where did",
"where's": "where is",
"who'll": "who will",
"who's": "who is",
"won't": "will not",
"wouldn't": "would not",
"you'd": "you would",
"you'll": "you will",
"you're": "you are",
"thx"   : "thanks"
}

# %%
def remove_contractions(tweet_text):
    return contractions[tweet_text.lower()] if tweet_text.lower() in contractions.keys() else tweet_text

# %%
def decontracted(phrase):
    # specific
    phrase = re.sub(r"won\'t", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    phrase = re.sub("spt", "seperti", phrase)
    #     loew = anda
    # gw = saya
    # dgn = dengan
    # sdh = sudah
    phrase = re.sub("loew", "anda", phrase)
    phrase = re.sub("gw", "saya", phrase)
    phrase = re.sub("dgn", "dengan", phrase)
    phrase = re.sub("sdh", "sudah", phrase)
    phrase = re.sub("banget", "sekali", phrase)
    phrase = re.sub("inget", "ingat", phrase)
    
    return phrase

# %%
data_df['Text Tweet']=data_df['Text Tweet'].apply(decontracted)
data_df['Text Tweet'][7]
# Out:
# 'b"Anehnya, keberanian imam baliho hanya di depan massanya. Dia seperti orgasme memghipnotis massa. Namun bila di depan hukum, he is nothing. @jokowi #jokowi #RingkusRijikBasmiFPI https://t.co/iUfcOZD08U"'

# %%
train['Text Tweet']=train['Text Tweet'].apply(remove_contractions)
train.tail()
# Out:
#                                              Text Tweet Sentiment
# 2035  b'Yang besok pada mau demo otaknya pada dimana...  negative
# 2036  b'YANG DEMO HABIB ANGAKATAN BERAPA NIH #sayabe...  negative
# 2037  b'Yang muslim sedang bingung tentang kemuslima...  negative
# 2038                            b'Yg bikin MASALAH &amp  negative
# 2039  b'Zona Merah Covid-19 Jabar Bertambah, Ridwan ...  negative

# %%
# test['tweet_text']=test['tweet_text'].apply(remove_contractions)
# test.tail()

# %%
# clean dataset
def clean_dataset(text):
    # To lowercase
    text = text.lower()
    # Remove hashtag while keeping hashtag text
    text = re.sub(r'# ...',' ', text)
    # Remove HTML special entities (e.g. &amp;)
    text = re.sub(r'\&\w*;', '', text)
    # Remove tickers
    text = re.sub(r'\$\w*', '', text)
    # Remove hyperlinks
    text = re.sub(r'https?:\/\/.*\/\w*', '', text)
    # Remove whitespace (including new line characters)
    text = re.sub(r'\s\s+',' ', text)
    text = re.sub(r'[ ]{2, }',' ',text)
    # Remove URL, RT, mention(@)
    text=  re.sub(r'http(\S)+', '',text)
    text=  re.sub(r'http ...', '',text)
    text=  re.sub(r'(RT|rt)[ ]*@[ ]*[\S]+','',text)
    text=  re.sub(r'RT[ ]?@','',text)
    text = re.sub(r'@[\S]+','',text)
    # Remove words with 2 or fewer letters
    text = re.sub(r'\b\w{1,2}\b', '', text)
    #&, < and >
    text = re.sub(r'&amp;?', 'and',text)
    text = re.sub(r'&lt;','<',text)
    text = re.sub(r'&gt;','>',text)
    # Insert space between words and punctuation marks
    text = re.sub(r'([\w\d]+)([^\w\d ]+)', '\1 \2',text)
    text = re.sub(r'([^\w\d ]+)([\w\d]+)', '\1 \2',text)
    # Remove characters beyond Basic Multilingual Plane (BMP) of Unicode:
    text= ''.join(c for c in text if c <= '\uFFFF') 
    text = text.strip()
    # Remove misspelling words
    text = ''.join(''.join(s)[:2] for _, s in itertools.groupby(text))
    # Remove punctuation
    text = ' '.join(re.sub("[\.\,\!\?\:\;\-\=\/\|\'\(\']", " ", text).split())
    # Remove emoji
    text = emoji.demojize(text)
    text = text.replace(":"," ")
    text = ' '.join(text.split()) 
    text = re.sub("([^\x00-\x7F])+"," ",text)
    # Remove Mojibake (also extra spaces)
    text = ' '.join(re.sub("[^\u4e00-\u9fa5\u0030-\u0039\u0041-\u005a\u0061-\u007a]", " ", text).split())
    return text

# %%
data_df['Text Tweet'] =data_df['Text Tweet'].apply(clean_dataset)
data_df.tail()
# Out:
#                                              Text Tweet Sentiment
# 2035  besok pada mau demo otaknya pada dimana udah t...  negative
# 2036                    demo habib angakatan berapa nih  negative
# 2037  muslim sedang bingung tentang kemusliman dan n...  negative
# 2038                                  bikin masalah and  negative
# 2039  merah jabar ridwan kamil larang perayaan tahun...  negative

# %%
train['Text Tweet'] =train['Text Tweet'].apply(clean_dataset)
train.tail()
# Out:
#                                              Text Tweet Sentiment
# 2035  besok pada mau demo otaknya pada dimana udah t...  negative
# 2036                    demo habib angakatan berapa nih  negative
# 2037  muslim sedang bingung tentang kemusliman dan n...  negative
# 2038                                  bikin masalah and  negative
# 2039  merah jabar ridwan kamil larang perayaan tahun...  negative

# %%
# test['tweet_text'] =test['tweet_text'].apply(clean_dataset)
# test.tail()

# %%
def encode_labels(df):
    for i, j in data_df.iterrows():
        if j['Sentiment']=='negative':
            j['Sentiment']=0
        # elif j['sentimen']=='neutral':
        #     j['sentimen']=1
        elif j['Sentiment']=='positive':
            j['Sentiment']=1
            
    return data_df

# %%
data_df
# Out:
#                                              Text Tweet Sentiment
# 0     ahli untuk memastikan potential suspect lain d...  negative
# 1     jadi lewat statement ini saja bahwa hidup ini ...  positive
# 2     menurut semua kekisruhan yang ini dimulai seja...  negative
# 3     nanti saya yang akan menjadi penerima divaksin...  positive
# 4     warga setiap umat islam pasti terlepas dari ma...  positive
# ...                                                 ...       ...
# 2035  besok pada mau demo otaknya pada dimana udah t...  negative
# 2036                    demo habib angakatan berapa nih  negative
# 2037  muslim sedang bingung tentang kemusliman dan n...  negative
# 2038                                  bikin masalah and  negative
# 2039  merah jabar ridwan kamil larang perayaan tahun...  negative
#
# [2040 rows x 2 columns]

# %%
data_df = encode_labels(data_df)

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
 
factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()
print(stopwords)
# Out:
# ['yang', 'untuk', 'pada', 'ke', 'para', 'namun', 'menurut', 'antara', 'dia', 'dua', 'ia', 'seperti', 'jika', 'jika', 'sehingga', 'kembali', 'dan', 'tidak', 'ini', 'karena', 'kepada', 'oleh', 'saat', 'harus', 'sementara', 'setelah', 'belum', 'kami', 'sekitar', 'bagi', 'serta', 'di', 'dari', 'telah', 'sebagai', 'masih', 'hal', 'ketika', 'adalah', 'itu', 'dalam', 'bisa', 'bahwa', 'atau', 'hanya', 'kita', 'dengan', 'akan', 'juga', 'ada', 'mereka', 'sudah', 'saya', 'terhadap', 'secara', 'agar', 'lain', 'anda', 'begitu', 'mengapa', 'kenapa', 'yaitu', 'yakni', 'daripada', 'itulah', 'lagi', 'maka', 'tentang', 'demi', 'dimana', 'kemana', 'pula', 'sambil', 'sebelum', 'sesudah', 'supaya', 'guna', 'kah', 'pun', 'sampai', 'sedangkan', 'selagi', 'sementara', 'tetapi', 'apakah', 'kecuali', 'sebab', 'selain', 'seolah', 'seraya', 'seterusnya', 'tanpa', 'agak', 'boleh', 'dapat', 'dsb', 'dst', 'dll', 'dahulu', 'dulunya', 'anu', 'demikian', 'tapi', 'ingin', 'juga', 'nggak', 'mari', 'nanti', 'melainkan',
# ...

# %%
#stop = stopwords.words('english')
#stop+=['get','got','getting','one','two','would','still','could','going']#customized stop word list
#stop = [e for e in stop if e not in ("n't", "not", "no")]

# Exclude stopwords with Python's list comprehension and pandas.DataFrame.apply.

train['Text Tweet'] = train['Text Tweet'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))
train.head()
# Out:
#                                           Text Tweet Sentiment
# 0  ahli memastikan potential suspect peristiwa pe...         0
# 1  jadi lewat statement hidup adil semua punya pe...         1
# 2  semua kekisruhan dimulai sejak adanya statemen...         0
# 3  menjadi penerima divaksin pertama memberikan k...         1
# 4  warga umat islam terlepas mana kelompok golong...         1

# %%
# test['Text Tweet'] = test['Text Tweet'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))
# test.head()

# %%
# most common words in twitter dataset 
all_texts = []
for line in list(train['Text Tweet']):
    texts = line.split()
    for text in texts:
        all_texts.append(text)
# plot word frequency distribution of first few words
plt.figure(figsize=(12,5))
plt.xticks(fontsize=13, rotation=90)
fd = nltk.FreqDist(all_texts)
fd.plot(25,cumulative=False)
# log-log of all words 
word_counts = sorted(Counter(all_texts).values(), reverse=True)

# %%
# create a word frequency dictionary
wordfreq = Counter(all_texts)
# draw a Word Cloud with word frequencies
wordcloud = WordCloud(width=900,
                      height=500,
                      max_words=200,
                      max_font_size=100,
                      relative_scaling=0.5,
                      colormap='cubehelix_r',
                      normalize_plurals=True).generate_from_frequencies(wordfreq)
plt.figure(figsize=(17,14))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
print(all_texts[:30])
# Out:
# ['ahli', 'memastikan', 'potential', 'suspect', 'peristiwa', 'penyerangan', 'anggota', 'polri', 'kata', 'brigjen', 'jadi', 'lewat', 'statement', 'hidup', 'adil', 'semua', 'punya', 'peran', 'proses', 'hadapi', 'bijak', 'segala', 'hormat', 'bertanggung', 'jawab', 'ujar', 'ridwan', 'semua', 'kekisruhan', 'dimulai']

# %%
train["Text Tweet"][0]
# Out:
# 'ahli memastikan potential suspect peristiwa penyerangan anggota polri kata brigjen'

# %%
data2 = data_df["Text Tweet"].to_csv('/content/data_cleaned.csv',index=False)

# %%
toBeCleanedNew='[%s]' % ' '.join(map(str, all_texts))#remove all the quation marks and commas. 
#print(toBeCleanedNew)

# %%
len(wordfreq)#the whole vocabulary size in train dataset
# Out:
# 4823

# %%
#You need to install version==0.4.2 to run hugging face tokenizer on kaggle
# !pip --no-cache-dir install tokenizers==0.4.2 #you get only a warning, just ignore it

# %%
# #!pip install tokenizers #hugging face tokenizer
# from tokenizers import (ByteLevelBPETokenizer,
#                             CharBPETokenizer,
#                             SentencePieceBPETokenizer,
#                             BertWordPieceTokenizer)
# tokenizer = SentencePieceBPETokenizer()
# #Kaggle has a restriction to write file directly to the server, I download the cleaned corpus and uploaded it back.
# path="/content/input/data_cleaned.txt"
# #set vocab_size to 15000 as the len(train_set)was something like 12500 
# tokenizer.train(files=path, vocab_size=15_000, min_frequency=2, special_tokens=[
#    "<pad>",
#    "<s>",
#    "</s>",
#    "<unk>",
#    "<mask>",
# ])

# %%
#!pip install tokenizers #hugging face tokenizer
from tokenizers import (ByteLevelBPETokenizer,
                            CharBPETokenizer,
                            SentencePieceBPETokenizer,
                            BertWordPieceTokenizer)
tokenizer = SentencePieceBPETokenizer()
#Kaggle has a restriction to write file directly to the server, I download the cleaned corpus and uploaded it back.
path="/content/input/data_cleaned_j.txt"
#set vocab_size to 15000 as the len(train_set)was something like 12500 
tokenizer.train(files=path, vocab_size=15_000, min_frequency=2, special_tokens=[
   "<pad>",
   "<s>",
   "</s>",
   "<unk>",
   "<mask>",
])

# %%
# Now I got my trained corpus and it saved to my working directory.
tokenizer.save(".", "/content/working/tokenedText")
# Out:
# ['/content/working/tokenedText-vocab.json',
#  '/content/working/tokenedText-merges.txt']

# %%
#let's try to tokenize the first sentence
output = tokenizer.encode("untuk memastikan potential suspect (tersangka) lain dalam peristiwa penyerangan anggota Polri tersebut")
#print(output)
print(output.ids,output.tokens, output.offsets)
# Out:
# [42, 274, 80, 1507, 2068, 4825, 3011, 31, 692, 35, 2274, 912, 54, 83, 959, 1562, 3381, 535, 42, 2163, 989] ['▁', 'unt', 'uk', '▁memastikan', '▁pot', 'ential', '▁sus', 'p', 'ec', 't', '▁tersangka', '▁la', 'in', '▁d', 'alam', '▁peristiwa', '▁penyerangan', '▁anggota', '▁', 'olri', '▁tersebut'] [(0, 1), (1, 4), (4, 6), (6, 17), (17, 21), (21, 27), (27, 31), (31, 32), (32, 34), (34, 35), (35, 45), (47, 50), (50, 52), (52, 54), (54, 58), (58, 68), (68, 80), (80, 88), (88, 89), (89, 93), (94, 103)]

# %%
#convert it back :)
decode=tokenizer.decode([42, 357, 2231, 1502, 6423, 3079, 31, 602, 35, 2868, 4702, 99, 1423, 1891, 4643, 738, 42, 97, 70, 1388])
print(decode)
# Out:
# ovtrasiibatonopwatkataecutol sesuaiadap konvo tunt emb di disebut

# %%
# As we don't have label for test dataset, I will split train dataset as trainsub and testsub dataset.
from sklearn.model_selection import train_test_split
X_subtrain, X_subtest, y_subtrain, y_subtest = train_test_split( train['Text Tweet'],train['Sentiment'], test_size=0.2, random_state=42)

# %%
X_subtrain.head()
# Out:
# 1305    melalui menkopolhukam menugaskan penyelesaian ...
# 1848    penembakan laskar komnas presiden berikan aten...
# 1702    gubernur jawa timur khofifah indar parawansa m...
# 1561    gubernur jawa barat ridwan kamil menyebut menk...
# 1610    takbir rossullalah bukan buat teriak teriak om...
# Name: Text Tweet, dtype: object

# %%
X_subtest.head()
# Out:
# 1316    menyampaikan kabar vsksin diberikan gratis mas...
# 1000    perayaan natal terutama tahun pemerintah melar...
# 1068                            berita soal nongol berita
# 1967    selamat ulang anies wakilnya anggap jakmania b...
# 529                           polisi punya celah menjerat
# Name: Text Tweet, dtype: object

# %%
y_subtrain.head()
# Out:
# 1305    1
# 1848    0
# 1702    1
# 1561    0
# 1610    0
# Name: Sentiment, dtype: object

# %%
# import trained corpus to tokenize our dataframe

from tokenizers.implementations import SentencePieceBPETokenizer
from tokenizers.processors import BertProcessing

tokenizer =SentencePieceBPETokenizer(
    '/content/working/tokenedText-vocab.json',
    '/content/working/tokenedText-merges.txt', 
)
tokenizer._tokenizer.post_processor = BertProcessing(
   ("</s>", tokenizer.token_to_id("</s>")),
  ("<s>", tokenizer.token_to_id("<s>")),
)
tokenizer.enable_truncation(max_length=512)

X_subtrain_tokened=X_subtrain.apply(lambda x:tokenizer.encode(x).ids)
X_subtrain_tokened.head()
# Out:
# 1305    [1, 925, 2272, 4023, 5280, 122, 34, 308, 333, ...
# 1848    [1, 549, 215, 844, 138, 92, 1316, 345, 1227, 1...
# 1702    [1, 531, 403, 1960, 3641, 4383, 4740, 2233, 26...
# 1561    [1, 531, 403, 384, 237, 243, 1046, 725, 975, 2...
# 1610    [1, 5073, 71, 5262, 350, 683, 2582, 2582, 5157...
# Name: Text Tweet, dtype: object

# %%
X_subtest_tokened=X_subtest.apply(lambda x:tokenizer.encode(x).ids)
X_subtest_tokened.head()
# Out:
# 1316    [1, 591, 652, 91, 2899, 1601, 1106, 296, 230, ...
# 1000    [1, 2162, 1268, 2581, 316, 311, 4374, 1305, 70...
# 1068                  [1, 878, 292, 107, 246, 99, 878, 2]
# 1967    [1, 1377, 2312, 483, 5031, 405, 69, 4037, 28, ...
# 529                     [1, 352, 697, 5128, 167, 2446, 2]
# Name: Text Tweet, dtype: object

# %%
y_subtrain.head()
# Out:
# 1305    1
# 1848    0
# 1702    1
# 1561    0
# 1610    0
# Name: Sentiment, dtype: object

# %%
y_subtest.head()
# Out:
# 1316    1
# 1000    1
# 1068    0
# 1967    1
# 529     0
# Name: Sentiment, dtype: object

# %%
# the original test dataset (without label)
# test["Tokened_Text"]=test["tweet_text"].apply(lambda x:tokenizer.encode(x).ids)
# test.head()

# %%
# test.drop('sentimen', axis=1, inplace=True)

# %%
# test

# %%
#check Vocabulary (VOCAB_SIZE) in test dataset
from collections import Counter
subtrain_tokened=[]
for i in X_subtrain_tokened:
    subtrain_tokened+=i
print("Total amount of tokens in train dataset is:", len(subtrain_tokened))
distinct_list= (Counter(subtrain_tokened).keys())
print("The vocabulary size in subtrain dataset is :",len(distinct_list))
# Out:
# Total amount of tokens in train dataset is: 22044
# The vocabulary size in subtrain dataset is : 3661

# %%
#print(distinct_list)
print(max(distinct_list))
# Out:
# 5295

# %%
#check Vocabulary (VOCAB_SIZE) in test dataset
subtest_tokened=[]
for i in X_subtest_tokened:
    subtest_tokened+=i
print("Total amount of tokens in train dataset is:", len(subtest_tokened))
distinct_list_2= (Counter(subtest_tokened).keys())
print("The vocabulary size in subtrain dataset is :",len(distinct_list_2))
# Out:
# Total amount of tokens in train dataset is: 5449
# The vocabulary size in subtrain dataset is : 1978

# %%
# length distribution in tokened subtrain dataset
subtrain_length_dist=[]
i=0
for l in X_subtrain_tokened:
    subtrain_length_dist+=[len(l)]
y = np.array(subtrain_length_dist)
sns.distplot(y);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# length distribution in tokened subtest dataset
subtest_length_dist=[]
i=0
for l in X_subtest_tokened:
    subtest_length_dist+=[len(l)]
y = np.array(subtest_length_dist)
sns.distplot(y);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
X_subtrain.head()
X_subtrain_tokened.head()
# Out:
# 1305    [1, 925, 2272, 4023, 5280, 122, 34, 308, 333, ...
# 1848    [1, 549, 215, 844, 138, 92, 1316, 345, 1227, 1...
# 1702    [1, 531, 403, 1960, 3641, 4383, 4740, 2233, 26...
# 1561    [1, 531, 403, 384, 237, 243, 1046, 725, 975, 2...
# 1610    [1, 5073, 71, 5262, 350, 683, 2582, 2582, 5157...
# Name: Text Tweet, dtype: object

# %%
import keras
max_len=30
x_train = keras.preprocessing.sequence.pad_sequences(X_subtrain_tokened, maxlen=max_len)
x_test = keras.preprocessing.sequence.pad_sequences(X_subtest_tokened, maxlen=max_len)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (1632, 30)
# x_test shape: (408, 30)

# %%
import tensorflow as tf
embedding_dim=128
vocab_size=9940
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_len),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16)),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
    # tf.keras.layers.Dense(1, activation='gelu')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()#
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, 30, 128)           1272320
# _________________________________________________________________
# bidirectional (Bidirectional (None, 30, 128)           98816
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 30, 64)            41216
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 30, 32)            10368
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 32)                6272
# _________________________________________________________________
# dense (Dense)                (None, 24)                792
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 25
# ...

# %%
y_train= np.asarray(y_subtrain).astype(np.float64)
y_test= np.asarray(y_subtest).astype(np.float64)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.callbacks import TensorBoard
import datetime
from tensorflow.python.keras.callbacks import TensorBoard

logs_base_dir = "./logs"
logdir = os.path.join(logs_base_dir, datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=8)

# %%
history=model.fit(x_train, y_train,
          batch_size=12,
          epochs=30,
          validation_data=[x_test, y_test])
# Out:
# Epoch 1/30
# 136/136 [==============================] - 15s 48ms/step - loss: nan - accuracy: 0.4988 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 136/136 [==============================] - 5s 35ms/step - loss: nan - accuracy: 0.5212 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 136/136 [==============================] - 5s 34ms/step - loss: nan - accuracy: 0.5183 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 136/136 [==============================] - 4s 33ms/step - loss: nan - accuracy: 0.5268 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 136/136 [==============================] - 4s 32ms/step - loss: nan - accuracy: 0.5052 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 136/136 [==============================] - 4s 32ms/step - loss: nan - accuracy: 0.5198 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 7/30
# ...

# %%
# submission=pd.read_csv('/content/input/sample_submission.csv')
